# %%
import state_utils

state_utils.set_cohort("Poyet")
state_utils.set_host("ao")
state_utils.set_midas_db_type("standard")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import config
import os

# %%
letter_list = ["A","B","C"]

# %%
analysis_dir = config.analysis_directory

all_species = os.listdir("%s/clusters/Poyet/%s" % (analysis_dir,config.host))

# %%
spec_df = pd.read_csv("%sspecies/relative_abundance.txt.bz2" % config.data_directory,index_col=0,sep="\t")

# %%
tot_strain_df = pd.DataFrame(columns=config.host_samples)

# %%
x = np.random.normal(0,1,100000)
plt.hist(x,bins=50);

p = np.percentile(x,np.linspace(0,100,30))
for f in p:
    plt.axvline(f,color="red",zorder=10,alpha=.7)

# %%
df_all

# %%
species="Alistipes_putredinis_61533"
cluster_dir = "%s/clusters/Poyet/%s/%s" % (analysis_dir,config.host,species)

strain_snv_dic = {}
strain_centroid_dic = {}
i = 0

for strain in os.listdir(cluster_dir):

    strain_label = "%s_%s" % (species,letter_list[i])
    df = pd.read_csv("%s/%s" % (cluster_dir,strain),index_col=0)
    strain_snv_dic[strain_label] = df
    strain_centroid_dic[strain_label] = df.median()
    i+=1

# %%
strain_centroid_dic = pd.DataFrame(strain_centroid_dic)
spec_strain_df = spec_df.loc[species]*strain_centroid_dic.T

# %%
spec_strain_df = {}

# %%
tot_strain_df = pd.DataFrame(columns=config.dates.index)

# %%
for species in all_species:
    
    cluster_dir = "%s/clusters/Poyet/%s/%s" % (analysis_dir,config.host,species)

    strain_snv_dic = {}
    strain_centroid_dic = {}
    i = 0

    for strain in os.listdir(cluster_dir):
        
        strain_label = "%s_%s" % (species,letter_list[i])
        df = pd.read_csv("%s/%s" % (cluster_dir,strain),index_col=0)
        strain_snv_dic[strain_label] = df
        strain_centroid_dic[strain_label] = df.median()
        
        print(strain_centroid_dic[strain_label].min() == 1)
        
        i+=1
    
    strain_centroid_dic = pd.DataFrame(strain_centroid_dic)
    
    if strain_centroid_dic.shape[1] < 2:
        if strain_centroid_dic["%s_%s" % (species,letter_list[0])].min() != 1.0:
            strain_centroid_dic["%s_%s" % (species,letter_list[1])] = 1 - strain_centroid_dic["%s_%s" % (species,letter_list[0])]

    spec_strain_df = spec_df.loc[species]*strain_centroid_dic.T
    
    for idx in spec_strain_df.index:
        tot_strain_df.loc[idx] = spec_strain_df.loc[idx]
# Out:
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# True
# True

# %%
tot_strain_df.loc["Parabacteroides_distasonis_56985_A"].count()
# Out:
# 37

# %%
fig,ax = plt.subplots(figsize=(12,8))
tot_strain_df.loc["Ruminococcus_bromii_62047_A"].plot(legend=None,ax=ax)
tot_strain_df.loc["Bacteroides_vulgatus_57955_B"].plot(legend=None,ax=ax)

#ax.semilogy()

# %%
tot_strain_df.loc["Ruminococcus_bromii_62047_A"].dropna().plot()

# %%
tot_strain_df.loc["Bacteroides_cellulosilyticus_58046_A"].dropna()

# %%
tot_strain_df.loc["Bacteroides_massiliensis_44749_A"].dropna()

# %%
tot_strain_df.columns = config.dates.loc[tot_strain_df.columns]

# %%
obs_data = tot_strain_df.loc["Bacteroides_ovatus_58035_A"].dropna()
strain_dates = obs_data.index
train_num = int(len(obs_data)/2) - 1
train_num
train_num = np.argmin(abs((strain_dates.values - strain_dates[-1]/2)))

# %%
from sklearn.metrics import auc

# %%
dates = config.dates

# %%
strain = "Faecalibacterium_prausnitzii_61481_B"
obs_data = tot_strain_df.loc[strain]
obs_data = obs_data[obs_data.notna()]
strain_dates = dates.loc[obs_data.index].sort_values()
obs_data = obs_data.loc[strain_dates.index]
#train_num = int(len(obs_data)/2)
train_num = np.argmin(abs((strain_dates.values - 2.0*strain_dates[-1]/3)))

# %%
train_num

# %%
np.argwhere(strain_dates.index == config.dates.index[train_num])

# %%
train_num

# %%
obs_data[:train_num].mean()

# %%
auc(strain_dates[:train_num],obs_data[:train_num])/(strain_dates[train_num] - strain_dates[0])

# %%
plt.plot(obs_data.values[:train_num])
plt.plot(obs_data.values[train_num:])

# %%
obs_data.values.mean()

# %%
obs_data

# %%
train_num = int(len(obs_data)/2)

# %%
train_num = np.argmin(abs((strain_dates.values - strain_dates[-1]/2)))

# %%
plt.plot(strain_dates.values,obs_data.values)
plt.axvline(strain_dates.values[train_num])

# %%
obs_data[:120]

# %%
fig,ax = plt.subplots(figsize=(12,8))

tot_strain_df.loc["Faecalibacterium_prausnitzii_61481_A"].dropna().plot()
tot_strain_df.loc["Faecalibacterium_prausnitzii_61481_B"].dropna().plot()
ax.axvline(strain_dates[train_num])

# %%
tot_strain_df = tot_strain_df.dropna(axis=1,how="all")

# %%
tot_strain_df
# Out:
# run_accession                         SRR9224065  SRR9224066  SRR9224067  \
# Eubacterium_eligens_61678_A             0.041906    0.184996         NaN
# Bifidobacterium_adolescentis_56815_A         NaN         NaN         NaN
# Ruminococcus_bicirculans_59300_A        0.034204    0.028042    0.027675
# Faecalibacterium_prausnitzii_62201_A         NaN    0.039918         NaN
# Dialister_invisus_61905_A                    NaN    0.033411    0.025473
# Bacteroides_uniformis_57318_A           0.157593    0.106318    0.213833
# Eubacterium_rectale_56927_A                  NaN    0.093121         NaN
# Bacteroides_xylanisolvens_57185_A       0.004651    0.001310    0.008127
# Bacteroides_xylanisolvens_57185_B       0.060464    0.017680    0.071984
# Bacteroides_ovatus_58035_A              0.322253    0.104885    0.326938
# Bacteroides_ovatus_58035_B              0.019530    0.006555    0.024608
# Faecalibacterium_prausnitzii_61481_A         NaN    0.102017         NaN
# Faecalibacterium_prausnitzii_61481_B         NaN    0.009716         NaN
# Bacteroides_fragilis_54507_A            0.130731    0.088183    0.098247
# Parabacteroides_distasonis_56985_A           NaN         NaN         NaN
#
# run_accession                         SRR9224068  SRR9224069  SRR9224070  \
# Eubacterium_eligens_61678_A             0.163691    0.048884    0.049934
# Bifidobacterium_adolescentis_56815_A    0.075482    0.034775    0.028510
# Ruminococcus_bicirculans_59300_A             NaN    0.035018    0.050155
# Faecalibacterium_prausnitzii_62201_A    0.028534    0.084300    0.046993
# Dialister_invisus_61905_A               0.033899    0.043217         NaN
# Bacteroides_uniformis_57318_A           0.045163    0.105061    0.108443
# Eubacterium_rectale_56927_A             0.189156    0.030989    0.024779
# Bacteroides_xylanisolvens_57185_A            NaN    0.005351    0.012275
# Bacteroides_xylanisolvens_57185_B            NaN    0.039401    0.068742
# Bacteroides_ovatus_58035_A              0.039033    0.184395    0.265562
# Bacteroides_ovatus_58035_B              0.003903    0.016034    0.030560
# Faecalibacterium_prausnitzii_61481_A    0.089458    0.059280    0.015885
# Faecalibacterium_prausnitzii_61481_B    0.008946    0.011292    0.005957
# Bacteroides_fragilis_54507_A            0.039456    0.140909    0.147023
# Parabacteroides_distasonis_56985_A           NaN         NaN         NaN
#
# run_accession                         SRR9224071  SRR9224072  SRR9224073  \
# Eubacterium_eligens_61678_A             0.070145    0.165657    0.026517
# Bifidobacterium_adolescentis_56815_A    0.019268    0.124067    0.046727
# Ruminococcus_bicirculans_59300_A        0.058151    0.019743    0.031409
# Faecalibacterium_prausnitzii_62201_A    0.036111    0.101045    0.019973
# Dialister_invisus_61905_A               0.022144         NaN    0.036943
# Bacteroides_uniformis_57318_A           0.144775    0.032197    0.115566
# Eubacterium_rectale_56927_A                  NaN    0.028079    0.027853
# Bacteroides_xylanisolvens_57185_A       0.003889         NaN    0.010714
# Bacteroides_xylanisolvens_57185_B       0.049265         NaN    0.068747
# Bacteroides_ovatus_58035_A              0.260848    0.084562    0.289043
# Bacteroides_ovatus_58035_B              0.016752    0.003844    0.023804
# Faecalibacterium_prausnitzii_61481_A    0.017573    0.033575    0.018627
# Faecalibacterium_prausnitzii_61481_B    0.009763    0.021584    0.012418
# Bacteroides_fragilis_54507_A            0.161441    0.053119    0.116407
# Parabacteroides_distasonis_56985_A           NaN         NaN         NaN
#
# run_accession                         SRR9224074  ...  SRR9224256  SRR9224255  \
# Eubacterium_eligens_61678_A             0.036397  ...    0.093353    0.054993
# Bifidobacterium_adolescentis_56815_A    0.038901  ...    0.036515         NaN
# Ruminococcus_bicirculans_59300_A        0.029690  ...         NaN         NaN
# Faecalibacterium_prausnitzii_62201_A    0.049284  ...    0.065818    0.049907
# Dialister_invisus_61905_A               0.035033  ...    0.029367         NaN
# Bacteroides_uniformis_57318_A           0.125383  ...    0.076129    0.143030
# Eubacterium_rectale_56927_A             0.032564  ...    0.023026         NaN
# Bacteroides_xylanisolvens_57185_A       0.005584  ...    0.001362    0.001667
# Bacteroides_xylanisolvens_57185_B       0.053356  ...    0.039955    0.045843
# Bacteroides_ovatus_58035_A              0.265521  ...    0.283056    0.367447
# Bacteroides_ovatus_58035_B              0.015361  ...    0.007791    0.011135
# Faecalibacterium_prausnitzii_61481_A    0.020621  ...    0.013655         NaN
# Faecalibacterium_prausnitzii_61481_B    0.017184  ...    0.035502         NaN
# Bacteroides_fragilis_54507_A            0.153361  ...    0.104040    0.084921
# Parabacteroides_distasonis_56985_A           NaN  ...    0.027336         NaN
#
# run_accession                         SRR9224288  SRR9224253  SRR9224258  \
# Eubacterium_eligens_61678_A             0.077948    0.094631    0.014228
# Bifidobacterium_adolescentis_56815_A    0.031736    0.096587    0.015072
# Ruminococcus_bicirculans_59300_A             NaN         NaN    0.015891
# Faecalibacterium_prausnitzii_62201_A    0.045726    0.075915    0.109238
# Dialister_invisus_61905_A               0.039676    0.056459    0.045141
# Bacteroides_uniformis_57318_A           0.122334    0.096392    0.118245
# Eubacterium_rectale_56927_A                  NaN         NaN    0.046576
# Bacteroides_xylanisolvens_57185_A       0.001605    0.002518    0.003700
# Bacteroides_xylanisolvens_57185_B       0.032631    0.021824    0.033694
# Bacteroides_ovatus_58035_A              0.216860    0.106118    0.161809
# Bacteroides_ovatus_58035_B              0.008341    0.008604    0.010372
# Faecalibacterium_prausnitzii_61481_A    0.010946    0.008870    0.005157
# Faecalibacterium_prausnitzii_61481_B    0.016420    0.026609    0.071672
# Bacteroides_fragilis_54507_A            0.116358    0.092215    0.146658
# Parabacteroides_distasonis_56985_A      0.055625    0.034276    0.031028
#
# run_accession                         SRR9224257  SRR9224472  SRR9224473  \
# Eubacterium_eligens_61678_A             0.045509    0.024787         NaN
# Bifidobacterium_adolescentis_56815_A         NaN         NaN    0.047104
# Ruminococcus_bicirculans_59300_A        0.050234    0.054719    0.037220
# Faecalibacterium_prausnitzii_62201_A    0.077489    0.034504    0.047564
# Dialister_invisus_61905_A               0.035768    0.040377    0.044926
# Bacteroides_uniformis_57318_A           0.164597    0.165848    0.114230
# Eubacterium_rectale_56927_A             0.022826         NaN         NaN
# Bacteroides_xylanisolvens_57185_A       0.001830    0.001397    0.001543
# Bacteroides_xylanisolvens_57185_B       0.023786    0.039125    0.044757
# Bacteroides_ovatus_58035_A              0.154540    0.307839    0.335168
# Bacteroides_ovatus_58035_B              0.008353    0.009054    0.009059
# Faecalibacterium_prausnitzii_61481_A    0.007666    0.002467         NaN
# Faecalibacterium_prausnitzii_61481_B    0.045997    0.022207         NaN
# Bacteroides_fragilis_54507_A            0.112939    0.073754    0.077729
# Parabacteroides_distasonis_56985_A      0.031136    0.024647    0.032377
#
# run_accession                         SRR9224470  SRR9224471
# Eubacterium_eligens_61678_A             0.033833         NaN
# Bifidobacterium_adolescentis_56815_A    0.050283    0.016374
# Ruminococcus_bicirculans_59300_A        0.043151    0.053415
# Faecalibacterium_prausnitzii_62201_A    0.047776    0.026495
# Dialister_invisus_61905_A                    NaN    0.022688
# Bacteroides_uniformis_57318_A           0.114707    0.224390
# Eubacterium_rectale_56927_A                  NaN         NaN
# Bacteroides_xylanisolvens_57185_A       0.001355    0.000748
# Bacteroides_xylanisolvens_57185_B       0.037262    0.034397
# Bacteroides_ovatus_58035_A              0.257304    0.306340
# Bacteroides_ovatus_58035_B              0.008168    0.005780
# Faecalibacterium_prausnitzii_61481_A    0.003389    0.002823
# Faecalibacterium_prausnitzii_61481_B    0.030503    0.029641
# Bacteroides_fragilis_54507_A            0.072993    0.051648
# Parabacteroides_distasonis_56985_A           NaN    0.020181
#
# [15 rows x 70 columns]

# %%
tot_strain_df.to_csv("strains_%s.csv" % config.host)

# %%
fig,ax = plt.subplots(figsize=(12,8))
tot_strain_df.T.plot(legend=None,ax=ax)
plt.semilogy();

# %%
fig,ax = plt.subplots(figsize=(12,8))

tot_strain_df.loc["Bacteroides_vulgatus_57955_A"].dropna().plot()
tot_strain_df.loc["Bacteroides_vulgatus_57955_B"].dropna().plot()
tot_strain_df.loc["Bacteroides_vulgatus_57955_C"].dropna().plot()

plt.semilogy();
